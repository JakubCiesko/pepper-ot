# %% [markdown]
# # Testing NaoQi Service
#
# Startup Choreographe Virtual robot and connect to it! Install the .pkg file onto the robot first!

# %%
import qi

robot_host = "127.0.0.1"
connection_url = "tcp://%s:43587" % robot_host
app = qi.Application(["PepperGroundedClientTest", "--qi-url=%s" % connection_url])
app.start()

# %%
app.session.services()
# Out:
# [{'endpoints': ['tcp://127.0.0.1:43587'],
#   'machineId': '231b86b6-73b3-46a8-a431-546ef538a3ee',
#   'name': 'ServiceDirectory',
#   'processId': 27627L,
#   'serviceId': 1L,
#   'sessionId': '0'},
#  {'endpoints': ['tcp://127.0.0.1:43587'],
#   'machineId': '231b86b6-73b3-46a8-a431-546ef538a3ee',
#   'name': 'LogManager',
#   'processId': 27627L,
#   'serviceId': 2L,
#   'sessionId': '0d9dc5e7-2cb7-4445-abee-12d300fb13e7'},
#  {'endpoints': ['tcp://127.0.0.1:43587'],
#   'machineId': '231b86b6-73b3-46a8-a431-546ef538a3ee',
#   'name': 'PackageManager',
#   'processId': 27627L,
#   'serviceId': 3L,
#   'sessionId': '0d9dc5e7-2cb7-4445-abee-12d300fb13e7'},
#  {'endpoints': ['tcp://127.0.0.1:43587'],
#   'machineId': '231b86b6-73b3-46a8-a431-546ef538a3ee',
#   'name': 'ALServiceManager',
#   'processId': 27627L,
#   'serviceId': 4L,
#   'sessionId': '0d9dc5e7-2cb7-4445-abee-12d300fb13e7'},
#  {'endpoints': ['tcp://127.0.0.1:33219'],
# ...

# %%
[service["name"] for service in app.session.services() if "grounded" in service["name"].lower()]
# Out:
# ['PepperGroundedClient']

# %%
service = app.session.service("PepperGroundedClient")

# %%
service.__dict__.keys()
# Out:
# ['setOutputLanguage',
#  'reloadConfig',
#  'resetMemory',
#  'scan',
#  'look',
#  'resetConversation',
#  'showMemory',
#  'getStatus',
#  'answerCachedQuestion',
#  'stop',
#  'say',
#  'askAboutObject',
#  'ask',
#  'refreshAndAsk',
#  'hideMemory',
#  'setServerBaseUrl',
#  'refreshMemoryConcepts']

# %%
service.ask("en", "What do you see now")

# %% [markdown]
# ```python
# [I] (1776455980.559794 32530 PepperGroundedClient: ask called lang_code=%s query=%s en What do you see now
# [I] 1776455980.561740 32530 PepperGroundedClient: TTS language set to %s English
# [I] 1776455980.562067 32530 PepperGroundedClient: Speaking text: %s Let me think about that.
# [I] 1776455981.571965 33268 PepperGroundedClient: Starting turn id=%s kind=%s ask_5a5d8ade885443da96a8238eca924985 ask
# [I] 1776455981.572142 33268 PepperGroundedClient: Starting ask with sanitized query %s What do you see now
# [I] 1776455981.572382 33268 PepperGroundedClient: HTTP %s %s POST https://raye-uncontractile-attently.ngrok-free.dev/api/v1/chat
# [I] 1776455990.265794 33268 PepperGroundedClient: HTTP response payload: %s {"chat_id": "-1", "confidence": 1.0, "metadata": {"conversation_in_language": "english", "crop_fallback_used_ids": [], "input_language": "english", "input_translation_applied": "False", "matched_object_count": 0, "matched_object_ids": [], "mode": "general", "model_id": "gemini-2.5-flash-lite", "object_label_requested": null, "object_label_resolved": null, "output_language": "english", "output_translation_applied": "False", "provider": "gemini"}, "sentence": "I SEE NOTHING RIGHT NOW", "source_object_ids": []}
# [I] 1776455990.266334 33268 PepperGroundedClient: Updating SessionStore after chat: %s {u'source_object_ids': [], u'confidence': 1.0, u'metadata': {u'model_id': u'gemini-2.5-flash-lite', u'output_language': u'english', u'matched_object_count': 0, u'object_label_requested': None, u'output_translation_applied': u'False', u'matched_object_ids': [], u'crop_fallback_used_ids': [], u'conversation_in_language': u'english', u'input_language': u'english', u'object_label_resolved': None, u'mode': u'general', u'provider': u'gemini', u'input_translation_applied': u'False'}, u'chat_id': u'-1', u'sentence': u'I SEE NOTHING RIGHT NOW'}
# [I] 1776455990.266965 33268 PepperGroundedClient: Speaking text: %s I SEE NOTHING RIGHT NOW
# [I] 1776455991.286495 33268 PepperGroundedClient: Completed turn id=%s kind=%s ask_5a5d8ade885443da96a8238eca924985 ask)
# ```

# %%
service.ask("cs", "Co vidis")

# %% [markdown]
# ```python
# [I] 1776456123.608379 32535 PepperGroundedClient: ask called lang_code=%s query=%s cs Co vidis
# [E] 1776456123.610095 32535 PepperGroundedClient: Speech failed for text: %s Podívám se na to.
# [I] 1776456123.611249 33701 PepperGroundedClient: Starting turn id=%s kind=%s ask_388cd0b37c194e40bbdd0f3ff57b2266 ask
# [I] 1776456123.611673 33701 PepperGroundedClient: Starting ask with sanitized query %s Co vidis
# [I] 1776456123.612157 33701 PepperGroundedClient: HTTP %s %s POST https://raye-uncontractile-attently.ngrok-free.dev/api/v1/chat
# [I] 1776456130.758086 33701 PepperGroundedClient: HTTP response payload: %s {"chat_id": "-1", "confidence": 1.0, "metadata": {"conversation_in_language": "czech", "crop_fallback_used_ids": [], "input_language": "eo", "input_translation_applied": "True", "matched_object_count": 0, "matched_object_ids": [], "mode": "general", "model_id": "gemini-2.5-flash-lite", "object_label_requested": null, "object_label_resolved": null, "output_language": "czech", "output_translation_applied": "True", "provider": "gemini"}, "sentence": "PR\u00c1V\u011a TE\u010e NIC NEVID\u00cdM", "source_object_ids": []}
# [I] 1776456130.758692 33701 PepperGroundedClient: Updating SessionStore after chat: %s {u'source_object_ids': [], u'confidence': 1.0, u'metadata': {u'model_id': u'gemini-2.5-flash-lite', u'output_language': u'czech', u'matched_object_count': 0, u'object_label_requested': None, u'output_translation_applied': u'True', u'matched_object_ids': [], u'crop_fallback_used_ids': [], u'conversation_in_language': u'czech', u'input_language': u'eo', u'object_label_resolved': None, u'mode': u'general', u'provider': u'gemini', u'input_translation_applied': u'True'}, u'chat_id': u'-1', u'sentence': u'PR\xc1V\u011a TE\u010e NIC NEVID\xcdM'}
# [I] 1776456130.759300 33701 PepperGroundedClient: Speaking text: %s PRÁVĚ TEĎ NIC NEVIDÍM
# [I] 1776456131.565399 33701 PepperGroundedClient: Completed turn id=%s kind=%s ask_388cd0b37c194e40bbdd0f3ff57b2266 ask
#
# ```

# %%
service.reloadConfig()

# %%
service.scan("en") # with fake camera adapter

# %% [markdown]
# ```python
# scan called lang_code=%s en
# [I] 1776456547.053758 32534 PepperGroundedClient: Speaking text: %s Scanning now.
# [I] 1776456547.468320 33928 PepperGroundedClient: Starting turn id=%s kind=%s scan_85503854b85b431a957d10e9688c57f5 scan
# [I] 1776456547.470913 33928 PepperGroundedClient: PoseAdapter.snapshot output: head_yaw=%s head_pitch=%s, body_yaw=%s 0.0183778535575 -0.257802546024 0.000571223441511
# [I] 1776456547.471402 33928 PepperGroundedClient: Starting scan sweep scan_id=%s pepper_scan_0cd454de3cac47b8922ea19ea7ec705b
# [I] 1776456547.473215 33928 PepperGroundedClient: Moved head to yaw=%s pitch=%s speed=%s -0.610865238198 -0.1 0.15
# [I] 1776456548.117329 33928 PepperGroundedClient: Captured frame frame_id=%s size=%sx%s hfov=%s vfov=%s pepper_frame_7dcf424a73b4420abfa9ef592ad255ba 640 480 0.5 0.5
# [I] 1776456548.119000 33928 PepperGroundedClient: PoseAdapter.snapshot output: head_yaw=%s head_pitch=%s, body_yaw=%s -0.509718418121 -0.0999905541539 0.000571223441511
# [I] 1776456548.119959 33928 PepperGroundedClient: Running PeopleAdapter.snapshot_people on people_ids=%s []
# [I] 1776456548.120399 33928 PepperGroundedClient: People snapshot contains %s visible people 0
# [I] 1776456548.121641 33928 PepperGroundedClient: Robot context snapshot ready, snapshot=%s {'social_people': [], 'sonar': None, 'pose': {'head_pitch': -0.09999055415391922, 'body_yaw': 0.0005712234415113926, 'head_yaw': -0.5097184181213379}, 'people': []}
# [I] 1776456548.122186 33928 PepperGroundedClient: Built metadata payload for frame_id=%s scan_id=%s, metadata=%s pepper_frame_7dcf424a73b4420abfa9ef592ad255ba pepper_scan_0cd454de3cac47b8922ea19ea7ec705b {'people': [], 'timestamp': 1776456548.11654, 'scan_id': u'pepper_scan_0cd454de3cac47b8922ea19ea7ec705b', 'head_yaw': -0.5097184181213379, 'frame_id': u'pepper_frame_7dcf424a73b4420abfa9ef592ad255ba', 'camera_vfov': 0.5, 'body_yaw': 0.0005712234415113926, 'camera_hfov': 0.5, 'capture_mode': 'scan', 'image_width': 640, 'image_height': 480, 'head_pitch': -0.09999055415391922}
# [I] 1776456548.123162 33928 PepperGroundedClient: Moved head to yaw=%s pitch=%s speed=%s 0.0 -0.1 0.15
# [I] 1776456548.742872 33928 PepperGroundedClient: Captured frame frame_id=%s size=%sx%s hfov=%s vfov=%s pepper_frame_21254392aa3e4f7ba0f341c9d37a4367 640 480 0.5 0.5
# [I] 1776456548.744852 33928 PepperGroundedClient: PoseAdapter.snapshot output: head_yaw=%s head_pitch=%s, body_yaw=%s -0.151609167457 -0.099999986589 0.000571223441511
# [I] 1776456548.746276 33928 PepperGroundedClient: Running PeopleAdapter.snapshot_people on people_ids=%s []
# [I] 1776456548.746700 33928 PepperGroundedClient: People snapshot contains %s visible people 0
# [I] 1776456548.748786 33928 PepperGroundedClient: Robot context snapshot ready, snapshot=%s {'social_people': [], 'sonar': None, 'pose': {'head_pitch': -0.09999998658895493, 'body_yaw': 0.0005712234415113926, 'head_yaw': -0.1516091674566269}, 'people': []}
# [I] 1776456548.749646 33928 PepperGroundedClient: Built metadata payload for frame_id=%s scan_id=%s, metadata=%s pepper_frame_21254392aa3e4f7ba0f341c9d37a4367 pepper_scan_0cd454de3cac47b8922ea19ea7ec705b {'people': [], 'timestamp': 1776456548.742123, 'scan_id': u'pepper_scan_0cd454de3cac47b8922ea19ea7ec705b', 'head_yaw': -0.1516091674566269, 'frame_id': u'pepper_frame_21254392aa3e4f7ba0f341c9d37a4367', 'camera_vfov': 0.5, 'body_yaw': 0.0005712234415113926, 'camera_hfov': 0.5, 'capture_mode': 'scan', 'image_width': 640, 'image_height': 480, 'head_pitch': -0.09999998658895493}
# [I] 1776456548.751153 33928 PepperGroundedClient: Moved head to yaw=%s pitch=%s speed=%s 0.610865238198 -0.1 0.15
# [I] 1776456549.376957 33928 PepperGroundedClient: Captured frame frame_id=%s size=%sx%s hfov=%s vfov=%s pepper_frame_467eaca23912492cb4911a7d91841e12 640 480 0.5 0.5
# [I] 1776456549.378956 33928 PepperGroundedClient: PoseAdapter.snapshot output: head_yaw=%s head_pitch=%s, body_yaw=%s 0.478541314602 -0.099999986589 0.000571223441511
# [I] 1776456549.380616 33928 PepperGroundedClient: Running PeopleAdapter.snapshot_people on people_ids=%s []
# [I] 1776456549.381349 33928 PepperGroundedClient: People snapshot contains %s visible people 0
# [I] 1776456549.382868 33928 PepperGroundedClient: Robot context snapshot ready, snapshot=%s {'social_people': [], 'sonar': None, 'pose': {'head_pitch': -0.09999998658895493, 'body_yaw': 0.0005712234415113926, 'head_yaw': 0.4785413146018982}, 'people': []}
# [I] 1776456549.383286 33928 PepperGroundedClient: Built metadata payload for frame_id=%s scan_id=%s, metadata=%s pepper_frame_467eaca23912492cb4911a7d91841e12 pepper_scan_0cd454de3cac47b8922ea19ea7ec705b {'people': [], 'timestamp': 1776456549.37612, 'scan_id': u'pepper_scan_0cd454de3cac47b8922ea19ea7ec705b', 'head_yaw': 0.4785413146018982, 'frame_id': u'pepper_frame_467eaca23912492cb4911a7d91841e12', 'camera_vfov': 0.5, 'body_yaw': 0.0005712234415113926, 'camera_hfov': 0.5, 'capture_mode': 'scan', 'image_width': 640, 'image_height': 480, 'head_pitch': -0.09999998658895493}
# [I] 1776456549.383749 33928 PepperGroundedClient: HTTP %s %s POST https://raye-uncontractile-attently.ngrok-free.dev/api/v1/detect/panorama
# [I] 1776456563.398429 33928 PepperGroundedClient: HTTP response payload: %s {"caption": "arafed image of a woman with glasses and a gray shirt", "caption_model_id": "Salesforce/blip-image-captioning-large", "caption_provider": "local_hf", "id": "8f7b7813-6403-4304-9654-3532d1033363", "image_height": 480, "image_width": 1920, "objects": [{"bbox": [1386.775146484375, 163.55474853515625, 1764.7474365234375, 476.39141845703125], "confidence": 0.9400666952133179, "label": "person", "object_id": 1}, {"bbox": [96.68692779541016, 167.6177215576172, 506.41375732421875, 476.5931396484375], "confidence": 0.9262589812278748, "label": "person", "object_id": 2}, {"bbox": [863.2299194335938, 220.870361328125, 1137.6470947265625, 476.78167724609375], "confidence": 0.9065801501274109, "label": "person", "object_id": 3}, {"bbox": [1278.1317138671875, 226.60641479492188, 1384.1156005859375, 326.052978515625], "confidence": 0.7161628007888794, "label": "tv", "object_id": 4}, {"bbox": [1726.147216796875, 173.29806518554688, 1894.583251953125, 283.05096435546875], "confidence": 0.6687366962432861, "label": "tv", "object_id": 5}, {"bbox": [1077.4666748046875, 288.8648986816406, 1223.588623046875, 397.199462890625], "confidence": 0.6351965665817261, "label": "tv", "object_id": 6}, {"bbox": [478.4287109375, 217.93704223632812, 632.369140625, 325.2671813964844], "confidence": 0.6216650605201721, "label": "tv", "object_id": 7}], "timestamp": 1776456562.5124984}
# [I] 1776456563.399187 33928 PepperGroundedClient: Updating SessionStore after detect: %s {u'objects': [{u'confidence': 0.9400666952133179, u'bbox': [1386.775146484375, 163.55474853515625, 1764.7474365234375, 476.39141845703125], u'object_id': 1, u'label': u'person'}, {u'confidence': 0.9262589812278748, u'bbox': [96.68692779541016, 167.6177215576172, 506.41375732421875, 476.5931396484375], u'object_id': 2, u'label': u'person'}, {u'confidence': 0.9065801501274109, u'bbox': [863.2299194335938, 220.870361328125, 1137.6470947265625, 476.78167724609375], u'object_id': 3, u'label': u'person'}, {u'confidence': 0.7161628007888794, u'bbox': [1278.1317138671875, 226.60641479492188, 1384.1156005859375, 326.052978515625], u'object_id': 4, u'label': u'tv'}, {u'confidence': 0.6687366962432861, u'bbox': [1726.147216796875, 173.29806518554688, 1894.583251953125, 283.05096435546875], u'object_id': 5, u'label': u'tv'}, {u'confidence': 0.6351965665817261, u'bbox': [1077.4666748046875, 288.8648986816406, 1223.588623046875, 397.199462890625], u'object_id': 6, u'label': u'tv'}, {u'confidence': 0.6216650605201721, u'bbox': [478.4287109375, 217.93704223632812, 632.369140625, 325.2671813964844], u'object_id': 7, u'label': u'tv'}], u'timestamp': 1776456562.5124984, u'caption_model_id': u'Salesforce/blip-image-captioning-large', u'image_width': 1920, u'caption': u'arafed image of a woman with glasses and a gray shirt', u'caption_provider': u'local_hf', u'image_height': 480, u'id': u'8f7b7813-6403-4304-9654-3532d1033363'}
# [I] 1776456563.399747 33928 PepperGroundedClient: Panorama scan completed objects=%s stick_together=%s 7 True
# [I] 1776456563.402390 33928 PepperGroundedClient: Moved head to yaw=%s pitch=%s speed=%s 0.0183778535575 -0.257802546024 0.15
# [I] 1776456563.603421 33928 PepperGroundedClient: HTTP %s %s GET https://raye-uncontractile-attently.ngrok-free.dev/api/v1/memory/summary?render_limit=5&lang=en
# [I] 1776456564.321637 33928 PepperGroundedClient: HTTP response payload: %s {"graph_svg": "<svg xmlns=\"http://www.w3.org/2000/svg\" width=\"850\" height=\"700\"..."obj": "person_2", "rel": "above", "sub": "tv_5"}, {"obj": "person_3", "rel": "above", "sub": "tv_5"}, {"obj": "tv_4", "rel": "above", "sub": "tv_5"}, {"obj": "tv_6", "rel": "above", "sub": "tv_5"}, {"obj": "tv_7", "rel": "above", "sub": "tv_5"}, {"obj": "person_2", "rel": "far_from", "sub": "tv_5"}, {"obj": "person_3", "rel": "far_from", "sub": "tv_5"}, {"obj": "tv_4", "rel": "far_from", "sub": "tv_5"}, {"obj": "tv_6", "rel": "far_from", "sub": "tv_5"}, {"obj": "tv_7", "rel": "far_from", "sub": "tv_5"}, {"obj": "person_1", "rel": "left_of", "sub": "tv_5"}, {"obj": "person_2", "rel": "left_of", "sub": "tv_5"}, {"obj": "person_3", "rel": "left_of", "sub": "tv_5"}, {"obj": "tv_4", "rel": "left_of", "sub": "tv_5"}, {"obj": "tv_6", "rel": "left_of", "sub": "tv_5"}, {"obj": "tv_7", "rel": "left_of", "sub": "tv_5"}, {"obj": "tv_4", "rel": "below", "sub": "tv_6"}, {"obj": "tv_5", "rel": "below", "sub": "tv_6"}, {"obj": "tv_7", "rel": "below", "sub": "tv_6"}, {"obj": "person_1", "rel": "far_from", "sub": "tv_6"}, {"obj": "person_2", "rel": "far_from", "sub": "tv_6"}, {"obj": "tv_5", "rel": "far_from", "sub": "tv_6"}, {"obj": "tv_7", "rel": "far_from", "sub": "tv_6"}, {"obj": "person_2", "rel": "left_of", "sub": "tv_6"}, {"obj": "person_3", "rel": "left_of", "sub": "tv_6"}, {"obj": "tv_7", "rel": "left_of", "sub": "tv_6"}, {"obj": "person_1", "rel": "right_of", "sub": "tv_6"}, {"obj": "tv_4", "rel": "right_of", "sub": "tv_6"}, {"obj": "tv_5", "rel": "right_of", "sub": "tv_6"}, {"obj": "person_1", "rel": "above", "sub": "tv_7"}, {"obj": "person_2", "rel": "above", "sub": "tv_7"}, {"obj": "person_3", "rel": "above", "sub": "tv_7"}, {"obj": "tv_6", "rel": "above", "sub": "tv_7"}, {"obj": "tv_5", "rel": "below", "sub": "tv_7"}, {"obj": "person_1", "rel": "far_from", "sub": "tv_7"}, {"obj": "person_3", "rel": "far_from", "sub": "tv_7"}, {"obj": "tv_4", "rel": "far_from", "sub": "tv_7"}, {"obj": "tv_5", "rel": "far_from", "sub": "tv_7"}, {"obj": "tv_6", "rel": "far_from", "sub": "tv_7"}, {"obj": "person_2", "rel": "left_of", "sub": "tv_7"}, {"obj": "person_1", "rel": "right_of", "sub": "tv_7"}, {"obj": "person_3", "rel": "right_of", "sub": "tv_7"}, {"obj": "tv_4", "rel": "right_of", "sub": "tv_7"}, {"obj": "tv_5", "rel": "right_of", "sub": "tv_7"}, {"obj": "tv_6", "rel": "right_of", "sub": "tv_7"}], "timestamp": 1776456563.807901}
# [I] 1776456564.329562 33928 PepperGroundedClient: Updating SessionStore after memory summary
# [I] 1776456564.332765 33928 PepperGroundedClient: Updated dynamic concept %s (%s entries, lang=%s) memory_objects 2 enu
# [I] 1776456564.335338 33928 PepperGroundedClient: Updated dynamic concept %s (%s entries, lang=%s) memory_attributes 8 enu
# [I] 1776456564.337227 33928 PepperGroundedClient: Updated dynamic concept %s (%s entries, lang=%s) memory_relations 10 enu
# [I] 1776456564.339973 33928 PepperGroundedClient: Updated dynamic concept %s (%s entries, lang=%s) memory_cached_questions 5 enu
# [I] 1776456564.340634 33928 PepperGroundedClient: Refreshed memory concepts objects=%s attrs=%s rels=%s questions=%s 2 8 10 5
# [I] 1776456564.341426 33928 PepperGroundedClient: HTTP %s %s POST https://raye-uncontractile-attently.ngrok-free.dev/api/v1/chat
# [I] 1776456565.855177 33928 PepperGroundedClient: HTTP response payload: %s {"chat_id": "-1", "confidence": 1.0, "metadata": {"conversation_in_language": "english", "crop_fallback_used_ids": [], "input_language": "english", "input_translation_applied": "False", "matched_object_count": 0, "matched_object_ids": [], "mode": "general", "model_id": "gemini-2.5-flash-lite", "object_label_requested": null, "object_label_resolved": null, "output_language": "english", "output_translation_applied": "False", "provider": "gemini"}, "sentence": "I SEE A MALE PERSON WITH GLASSES AND HAIR HE IS NEXT TO ANOTHER MALE PERSON WITH GLASSES AND HAIR THERE IS ALSO A BLACK BIG TV PRESENT", "source_object_ids": []}
# [I] 1776456565.855771 33928 PepperGroundedClient: Updating SessionStore after chat: %s {u'source_object_ids': [], u'confidence': 1.0, u'metadata': {u'model_id': u'gemini-2.5-flash-lite', u'output_language': u'english', u'matched_object_count': 0, u'object_label_requested': None, u'output_translation_applied': u'False', u'matched_object_ids': [], u'crop_fallback_used_ids': [], u'conversation_in_language': u'english', u'input_language': u'english', u'object_label_resolved': None, u'mode': u'general', u'provider': u'gemini', u'input_translation_applied': u'False'}, u'chat_id': u'-1', u'sentence': u'I SEE A MALE PERSON WITH GLASSES AND HAIR HE IS NEXT TO ANOTHER MALE PERSON WITH GLASSES AND HAIR THERE IS ALSO A BLACK BIG TV PRESENT'}
# [I] 1776456565.856401 33928 PepperGroundedClient: Speaking text: %s I SEE A MALE PERSON WITH GLASSES AND HAIR HE IS NEXT TO ANOTHER MALE PERSON WITH GLASSES AND HAIR THERE IS ALSO A BLACK BIG TV PRESENT
# [I] 1776456571.485853 33928 PepperGroundedClient: Completed turn id=%s kind=%s scan_85503854b85b431a957d10e9688c57f5 scan
#
# ```

# %%
service.showMemory("en")

# %% [markdown]
# ```python
# m", "sub": "tv_7"}, {"obj": "tv_5", "rel": "far_from", "sub": "tv_7"}, {"obj": "tv_6", "rel": "far_from", "sub": "tv_7"}, {"obj": "person_2", "rel": "left_of", "sub": "tv_7"}, {"obj": "person_1", "rel": "right_of", "sub": "tv_7"}, {"obj": "person_3", "rel": "right_of", "sub": "tv_7"}, {"obj": "tv_4", "rel": "right_of", "sub": "tv_7"}, {"obj": "tv_5", "rel": "right_of", "sub": "tv_7"}, {"obj": "tv_6", "rel": "right_of", "sub": "tv_7"}], "timestamp": 1776456694.9852085}
# [I] 1776456695.810468 34032 PepperGroundedClient: Updating SessionStore after memory summary
# [I] 1776456695.811814 34032 PepperGroundedClient: HTTP %s %s POST https://raye-uncontractile-attently.ngrok-free.dev/api/v1/chat/pregenerate_qa
# [I] 1776456697.442781 34032 PepperGroundedClient: HTTP response payload: %s {"metadata": {"generated_pair_count": 5, "model_id": "gemini-2.5-flash-lite", "output_language": "english", "provider": "gemini", "requested_pair_count": 5}, "pregenerated_qa": [{"answer": "There are 3 people in the scene.", "question": "How many people are in the scene?"}, {"answer": "There are 4 TVs in the scene.", "question": "How many TVs are in the scene?"}, {"answer": "Person 1 is sitting on person 3.", "question": "Who is sitting on person 3?"}, {"answer": "Person 1 is holding TV 5.", "question": "What is person 1 holding?"}, {"answer": "Person 2 is holding TV 7.", "question": "What is person 2 holding?"}]}
# [I] 1776456697.443702 34032 PepperGroundedClient: Updating SessionStore after pregenerated QA pairs=%s 5
# [I] 1776456697.446541 34032 PepperGroundedClient: Updated dynamic concept %s (%s entries, lang=%s) memory_objects 2 enu
# [I] 1776456697.449032 34032 PepperGroundedClient: Updated dynamic concept %s (%s entries, lang=%s) memory_attributes 8 enu
# [I] 1776456697.451081 34032 PepperGroundedClient: Updated dynamic concept %s (%s entries, lang=%s) memory_relations 10 enu
# [I] 1776456697.453244 34032 PepperGroundedClient: Updated dynamic concept %s (%s entries, lang=%s) memory_cached_questions 5 enu
# [I] 1776456697.453676 34032 PepperGroundedClient: Refreshed memory concepts objects=%s attrs=%s rels=%s questions=%s 2 8 10 5
# [I] 1776456697.455174 34032 PepperGroundedClient: ALTabletService unavailable
# [I] 1776456697.455602 34032 PepperGroundedClient: Speaking text: %s Something went wrong while I was processing that.
# [I] 1776456699.061896 34032 PepperGroundedClient: Completed turn id=%s kind=%s show_memory_060fca33a430469b8e6a72e365c89e9d show_memory
# ```
# AlTabletService is not available for virtual robot, no luck :(

# %%
from IPython.display import SVG, display
display(SVG("<svg xmlns=\"http://www.w3.org/2000/svg\" width=\"850\" height=\"700\" viewBox=\"0 0 850 700\" role=\"img\" aria-label=\"Pepper memory graph\"><rect width=\"100%\" height=\"100%\" fill=\"#f8fafc\"/><defs><marker id=\"arrow\" markerWidth=\"10\" markerHeight=\"7\" refX=\"9\" refY=\"3.5\" orient=\"auto\"><polygon points=\"0 0 10 3.5 0 7\" fill=\"#475569\"/></marker></defs>\n<g><line x1=\"425.0\" y1=\"460.0\" x2=\"145.0\" y2=\"460.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"239.0\" y=\"440.0\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"285.0\" y=\"454.0\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">below</text></g>\n<g><line x1=\"425.0\" y1=\"460.0\" x2=\"705.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"519.0\" y=\"262.5\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"565.0\" y=\"276.5\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">below</text></g>\n<g><line x1=\"425.0\" y1=\"460.0\" x2=\"145.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"239.0\" y=\"262.5\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"285.0\" y=\"276.5\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">below</text></g>\n<g><line x1=\"425.0\" y1=\"460.0\" x2=\"145.0\" y2=\"460.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"239.0\" y=\"440.0\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"285.0\" y=\"454.0\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">far_from</text></g>\n<g><line x1=\"425.0\" y1=\"460.0\" x2=\"705.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"519.0\" y=\"262.5\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"565.0\" y=\"276.5\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">far_from</text></g>\n<g><line x1=\"425.0\" y1=\"460.0\" x2=\"145.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"239.0\" y=\"262.5\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"285.0\" y=\"276.5\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">far_from</text></g>\n<g><line x1=\"425.0\" y1=\"460.0\" x2=\"145.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"239.0\" y=\"262.5\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"285.0\" y=\"276.5\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">left_of</text></g>\n<g><line x1=\"425.0\" y1=\"460.0\" x2=\"145.0\" y2=\"460.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"239.0\" y=\"440.0\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"285.0\" y=\"454.0\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">right_of</text></g>\n<g><line x1=\"425.0\" y1=\"460.0\" x2=\"705.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"519.0\" y=\"262.5\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"565.0\" y=\"276.5\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">right_of</text></g>\n<g><line x1=\"425.0\" y1=\"460.0\" x2=\"425.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"379.0\" y=\"262.5\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"425.0\" y=\"276.5\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">right_of</text></g>\n<g><line x1=\"145.0\" y1=\"460.0\" x2=\"425.0\" y2=\"460.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"239.0\" y=\"440.0\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"285.0\" y=\"454.0\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">above</text></g>\n<g><line x1=\"145.0\" y1=\"460.0\" x2=\"425.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"239.0\" y=\"262.5\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"285.0\" y=\"276.5\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">above</text></g>\n<g><line x1=\"145.0\" y1=\"460.0\" x2=\"705.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"379.0\" y=\"262.5\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"425.0\" y=\"276.5\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">below</text></g>\n<g><line x1=\"145.0\" y1=\"460.0\" x2=\"425.0\" y2=\"460.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"239.0\" y=\"440.0\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"285.0\" y=\"454.0\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">far_from</text></g>\n<g><line x1=\"145.0\" y1=\"460.0\" x2=\"705.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"379.0\" y=\"262.5\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"425.0\" y=\"276.5\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">far_from</text></g>\n<g><line x1=\"145.0\" y1=\"460.0\" x2=\"145.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"99.0\" y=\"262.5\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"145.0\" y=\"276.5\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">far_from</text></g>\n<g><line x1=\"145.0\" y1=\"460.0\" x2=\"425.0\" y2=\"460.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"239.0\" y=\"440.0\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"285.0\" y=\"454.0\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">left_of</text></g>\n<g><line x1=\"145.0\" y1=\"460.0\" x2=\"425.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"239.0\" y=\"262.5\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"285.0\" y=\"276.5\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">left_of</text></g>\n<g><line x1=\"145.0\" y1=\"460.0\" x2=\"145.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"99.0\" y=\"262.5\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"145.0\" y=\"276.5\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">left_of</text></g>\n<g><line x1=\"145.0\" y1=\"460.0\" x2=\"705.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"379.0\" y=\"262.5\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"425.0\" y=\"276.5\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">right_of</text></g>\n<g><line x1=\"705.0\" y1=\"105.0\" x2=\"425.0\" y2=\"460.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"519.0\" y=\"262.5\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"565.0\" y=\"276.5\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">above</text></g>\n<g><line x1=\"705.0\" y1=\"105.0\" x2=\"145.0\" y2=\"460.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"379.0\" y=\"262.5\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"425.0\" y=\"276.5\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">above</text></g>\n<g><line x1=\"705.0\" y1=\"105.0\" x2=\"425.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"519.0\" y=\"85.0\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"565.0\" y=\"99.0\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">above</text></g>\n<g><line x1=\"705.0\" y1=\"105.0\" x2=\"145.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"379.0\" y=\"85.0\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"425.0\" y=\"99.0\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">above</text></g>\n<g><line x1=\"705.0\" y1=\"105.0\" x2=\"425.0\" y2=\"460.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"519.0\" y=\"262.5\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"565.0\" y=\"276.5\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">far_from</text></g>\n<g><line x1=\"705.0\" y1=\"105.0\" x2=\"145.0\" y2=\"460.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"379.0\" y=\"262.5\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"425.0\" y=\"276.5\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">far_from</text></g>\n<g><line x1=\"705.0\" y1=\"105.0\" x2=\"425.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"519.0\" y=\"85.0\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"565.0\" y=\"99.0\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">far_from</text></g>\n<g><line x1=\"705.0\" y1=\"105.0\" x2=\"145.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"379.0\" y=\"85.0\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"425.0\" y=\"99.0\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">far_from</text></g>\n<g><line x1=\"705.0\" y1=\"105.0\" x2=\"425.0\" y2=\"460.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"519.0\" y=\"262.5\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"565.0\" y=\"276.5\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">left_of</text></g>\n<g><line x1=\"705.0\" y1=\"105.0\" x2=\"145.0\" y2=\"460.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"379.0\" y=\"262.5\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"425.0\" y=\"276.5\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">left_of</text></g>\n<g><line x1=\"705.0\" y1=\"105.0\" x2=\"425.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"519.0\" y=\"85.0\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"565.0\" y=\"99.0\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">left_of</text></g>\n<g><line x1=\"705.0\" y1=\"105.0\" x2=\"145.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"379.0\" y=\"85.0\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"425.0\" y=\"99.0\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">left_of</text></g>\n<g><line x1=\"425.0\" y1=\"105.0\" x2=\"145.0\" y2=\"460.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"239.0\" y=\"262.5\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"285.0\" y=\"276.5\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">below</text></g>\n<g><line x1=\"425.0\" y1=\"105.0\" x2=\"705.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"519.0\" y=\"85.0\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"565.0\" y=\"99.0\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">below</text></g>\n<g><line x1=\"425.0\" y1=\"105.0\" x2=\"145.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"239.0\" y=\"85.0\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"285.0\" y=\"99.0\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">below</text></g>\n<g><line x1=\"425.0\" y1=\"105.0\" x2=\"705.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"519.0\" y=\"85.0\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"565.0\" y=\"99.0\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">far_from</text></g>\n<g><line x1=\"425.0\" y1=\"105.0\" x2=\"145.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"239.0\" y=\"85.0\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"285.0\" y=\"99.0\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">far_from</text></g>\n<g><line x1=\"425.0\" y1=\"105.0\" x2=\"425.0\" y2=\"460.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"379.0\" y=\"262.5\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"425.0\" y=\"276.5\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">left_of</text></g>\n<g><line x1=\"425.0\" y1=\"105.0\" x2=\"145.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"239.0\" y=\"85.0\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"285.0\" y=\"99.0\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">left_of</text></g>\n<g><line x1=\"425.0\" y1=\"105.0\" x2=\"145.0\" y2=\"460.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"239.0\" y=\"262.5\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"285.0\" y=\"276.5\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">right_of</text></g>\n<g><line x1=\"425.0\" y1=\"105.0\" x2=\"705.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"519.0\" y=\"85.0\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"565.0\" y=\"99.0\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">right_of</text></g>\n<g><line x1=\"145.0\" y1=\"105.0\" x2=\"425.0\" y2=\"460.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"239.0\" y=\"262.5\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"285.0\" y=\"276.5\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">above</text></g>\n<g><line x1=\"145.0\" y1=\"105.0\" x2=\"425.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"239.0\" y=\"85.0\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"285.0\" y=\"99.0\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">above</text></g>\n<g><line x1=\"145.0\" y1=\"105.0\" x2=\"705.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"379.0\" y=\"85.0\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"425.0\" y=\"99.0\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">below</text></g>\n<g><line x1=\"145.0\" y1=\"105.0\" x2=\"425.0\" y2=\"460.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"239.0\" y=\"262.5\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"285.0\" y=\"276.5\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">far_from</text></g>\n<g><line x1=\"145.0\" y1=\"105.0\" x2=\"145.0\" y2=\"460.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"99.0\" y=\"262.5\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"145.0\" y=\"276.5\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">far_from</text></g>\n<g><line x1=\"145.0\" y1=\"105.0\" x2=\"705.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"379.0\" y=\"85.0\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"425.0\" y=\"99.0\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">far_from</text></g>\n<g><line x1=\"145.0\" y1=\"105.0\" x2=\"425.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"239.0\" y=\"85.0\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"285.0\" y=\"99.0\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">far_from</text></g>\n<g><line x1=\"145.0\" y1=\"105.0\" x2=\"425.0\" y2=\"460.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"239.0\" y=\"262.5\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"285.0\" y=\"276.5\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">right_of</text></g>\n<g><line x1=\"145.0\" y1=\"105.0\" x2=\"145.0\" y2=\"460.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"99.0\" y=\"262.5\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"145.0\" y=\"276.5\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">right_of</text></g>\n<g><line x1=\"145.0\" y1=\"105.0\" x2=\"705.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"379.0\" y=\"85.0\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"425.0\" y=\"99.0\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">right_of</text></g>\n<g><line x1=\"145.0\" y1=\"105.0\" x2=\"425.0\" y2=\"105.0\" stroke=\"#475569\" stroke-width=\"2\" marker-end=\"url(#arrow)\"/><rect x=\"239.0\" y=\"85.0\" width=\"92\" height=\"18\" rx=\"8\" ry=\"8\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1\"/><text x=\"285.0\" y=\"99.0\" text-anchor=\"middle\" font-size=\"12\" fill=\"#111827\">right_of</text></g>\n<g><g><defs><clipPath id=\"clip-50-40\"><rect x=\"50.0\" y=\"40\" width=\"190\" height=\"130\" rx=\"16\" ry=\"16\"/></clipPath></defs><rect x=\"50.0\" y=\"40\" width=\"190\" height=\"130\" rx=\"16\" ry=\"16\" fill=\"#ffffff\" stroke=\"#cbd5e1\" stroke-width=\"2\"/><image x=\"50.0\" y=\"40\" width=\"190\" height=\"130\" preserveAspectRatio=\"xMidYMid slice\" clip-path=\"url(#clip-50-40)\" href=\"data:image/jpeg;base64,...\"/></g><g><rect x=\"50\" y=\"180\" width=\"190\" height=\"20\" rx=\"10\" ry=\"10\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1.5\"/><text x=\"60\" y=\"194\" font-size=\"12\" fill=\"#111827\">tv_7</text></g><g><rect x=\"50\" y=\"206\" width=\"190\" height=\"20\" rx=\"10\" ry=\"10\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1.5\"/><text x=\"60\" y=\"220\" font-size=\"12\" fill=\"#111827\">is_big</text></g><g><rect x=\"50\" y=\"232\" width=\"190\" height=\"20\" rx=\"10\" ry=\"10\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1.5\"/><text x=\"60\" y=\"246\" font-size=\"12\" fill=\"#111827\">is_black</text></g></g>\n<g><g><defs><clipPath id=\"clip-330-40\"><rect x=\"330.0\" y=\"40\" width=\"190\" height=\"130\" rx=\"16\" ry=\"16\"/></clipPath></defs><rect x=\"330.0\" y=\"40\" width=\"190\" height=\"130\" rx=\"16\" ry=\"16\" fill=\"#ffffff\" stroke=\"#cbd5e1\" stroke-width=\"2\"/><image x=\"330.0\" y=\"40\" width=\"190\" height=\"130\" preserveAspectRatio=\"xMidYMid slice\" clip-path=\"url(#clip-330-40)\" href=\"data:image/jpeg;base64,...\"/></g><g><rect x=\"330\" y=\"180\" width=\"190\" height=\"20\" rx=\"10\" ry=\"10\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1.5\"/><text x=\"340\" y=\"194\" font-size=\"12\" fill=\"#111827\">tv_6</text></g><g><rect x=\"330\" y=\"206\" width=\"190\" height=\"20\" rx=\"10\" ry=\"10\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1.5\"/><text x=\"340\" y=\"220\" font-size=\"12\" fill=\"#111827\">is_big</text></g><g><rect x=\"330\" y=\"232\" width=\"190\" height=\"20\" rx=\"10\" ry=\"10\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1.5\"/><text x=\"340\" y=\"246\" font-size=\"12\" fill=\"#111827\">is_black</text></g></g>\n<g><g><defs><clipPath id=\"clip-610-40\"><rect x=\"610.0\" y=\"40\" width=\"190\" height=\"130\" rx=\"16\" ry=\"16\"/></clipPath></defs><rect x=\"610.0\" y=\"40\" width=\"190\" height=\"130\" rx=\"16\" ry=\"16\" fill=\"#ffffff\" stroke=\"#cbd5e1\" stroke-width=\"2\"/><image x=\"610.0\" y=\"40\" width=\"190\" height=\"130\" preserveAspectRatio=\"xMidYMid slice\" clip-path=\"url(#clip-610-40)\" href=\"data:image/jpeg;base64,...\"/></g><g><rect x=\"610\" y=\"180\" width=\"190\" height=\"20\" rx=\"10\" ry=\"10\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1.5\"/><text x=\"620\" y=\"194\" font-size=\"12\" fill=\"#111827\">tv_5</text></g><g><rect x=\"610\" y=\"206\" width=\"190\" height=\"20\" rx=\"10\" ry=\"10\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1.5\"/><text x=\"620\" y=\"220\" font-size=\"12\" fill=\"#111827\">is_big</text></g><g><rect x=\"610\" y=\"232\" width=\"190\" height=\"20\" rx=\"10\" ry=\"10\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1.5\"/><text x=\"620\" y=\"246\" font-size=\"12\" fill=\"#111827\">is_black</text></g></g>\n<g><g><defs><clipPath id=\"clip-50-395\"><rect x=\"50.0\" y=\"395\" width=\"190\" height=\"130\" rx=\"16\" ry=\"16\"/></clipPath></defs><rect x=\"50.0\" y=\"395\" width=\"190\" height=\"130\" rx=\"16\" ry=\"16\" fill=\"#ffffff\" stroke=\"#cbd5e1\" stroke-width=\"2\"/><image x=\"50.0\" y=\"395\" width=\"190\" height=\"130\" preserveAspectRatio=\"xMidYMid slice\" clip-path=\"url(#clip-50-395)\" href=\"data:image/jpeg;base64,...\"/></g><g><rect x=\"50\" y=\"535\" width=\"190\" height=\"20\" rx=\"10\" ry=\"10\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1.5\"/><text x=\"60\" y=\"549\" font-size=\"12\" fill=\"#111827\">tv_4</text></g><g><rect x=\"50\" y=\"561\" width=\"190\" height=\"20\" rx=\"10\" ry=\"10\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1.5\"/><text x=\"60\" y=\"575\" font-size=\"12\" fill=\"#111827\">is_big</text></g><g><rect x=\"50\" y=\"587\" width=\"190\" height=\"20\" rx=\"10\" ry=\"10\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1.5\"/><text x=\"60\" y=\"601\" font-size=\"12\" fill=\"#111827\">is_black</text></g></g>\n<g><g><defs><clipPath id=\"clip-330-395\"><rect x=\"330.0\" y=\"395\" width=\"190\" height=\"130\" rx=\"16\" ry=\"16\"/></clipPath></defs><rect x=\"330.0\" y=\"395\" width=\"190\" height=\"130\" rx=\"16\" ry=\"16\" fill=\"#ffffff\" stroke=\"#cbd5e1\" stroke-width=\"2\"/><image x=\"330.0\" y=\"395\" width=\"190\" height=\"130\" preserveAspectRatio=\"xMidYMid slice\" clip-path=\"url(#clip-330-395)\" href=\"data:image/jpeg;base64,...\"/></g><g><rect x=\"330\" y=\"535\" width=\"190\" height=\"20\" rx=\"10\" ry=\"10\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1.5\"/><text x=\"340\" y=\"549\" font-size=\"12\" fill=\"#111827\">person_3</text></g><g><rect x=\"330\" y=\"561\" width=\"190\" height=\"20\" rx=\"10\" ry=\"10\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1.5\"/><text x=\"340\" y=\"575\" font-size=\"12\" fill=\"#111827\">has_hair</text></g><g><rect x=\"330\" y=\"587\" width=\"190\" height=\"20\" rx=\"10\" ry=\"10\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1.5\"/><text x=\"340\" y=\"601\" font-size=\"12\" fill=\"#111827\">is_big</text></g><g><rect x=\"330\" y=\"613\" width=\"190\" height=\"20\" rx=\"10\" ry=\"10\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1.5\"/><text x=\"340\" y=\"627\" font-size=\"12\" fill=\"#111827\">is_black</text></g><g><rect x=\"330\" y=\"639\" width=\"190\" height=\"20\" rx=\"10\" ry=\"10\" fill=\"#ffffff\" stroke=\"#e2e8f0\" stroke-width=\"1.5\"/><text x=\"340\" y=\"653\" font-size=\"12\" fill=\"#111827\">wearing_glass</text></g></g></svg>"))

# %%
service.answerCachedQuestion("en", "How many people are in the scene?")

# %% [markdown]
# ```python
# [I] 1776456853.225620 32533 PepperGroundedClient: answerCachedQuestion called lang_code=%s question=%s en How many people are in the scene?
# [I] 1776456853.226664 34058 PepperGroundedClient: Starting turn id=%s kind=%s cached_answer_ac7cae686def4e07bc49793f270b8b79 cached_answer
# [I] 1776456853.227296 34058 PepperGroundedClient: Answering from pregenerated cache for query=%s How many people are in the scene?
# [I] 1776456853.227908 34058 PepperGroundedClient: Speaking text: %s There are 3 people in the scene.
# [I] 1776456854.632024 34058 PepperGroundedClient: Completed turn id=%s kind=%s cached_answer_ac7cae686def4e07bc49793f270b8b79 cached_answer
# ```
# instant response!

# %%
service.scan("cs")

# %%
tts = app.session.service("ALTextToSpeech")

# %%
tts.getLanguage()
# Out:
# 'Czech'
